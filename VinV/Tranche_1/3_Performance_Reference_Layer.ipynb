# %%
# ============================================================
# VinV – Performance Reference Layer
# Builds forward return targets from monthly features
# ============================================================

from pathlib import Path
import pandas as pd
import numpy as np

# ------------------------------------------------------------
# Paths
# ------------------------------------------------------------
ROOT = Path("..")
DATA_PROCESSED = ROOT / "data" / "processed"
ARTIFACTS = ROOT / "artifacts"

DATA_PROCESSED.mkdir(parents=True, exist_ok=True)
ARTIFACTS.mkdir(parents=True, exist_ok=True)

IN_FEATURES = DATA_PROCESSED / "vinv_inputs_raw.parquet"
OUT_TARGETS = DATA_PROCESSED / "vinv_targets_monthly.parquet"
OUT_DOCS    = ARTIFACTS / "target_definitions.md"

# %%
# load imports
df = pd.read_parquet(IN_FEATURES)

# required columns
req = {"date", "asset_id", "ret_m_total"}
missing = req - set(df.columns)
if missing:
    raise ValueError(f"Missing required columns: {missing}")

df = df.sort_values(["asset_id", "date"]).reset_index(drop=True)
