# %%
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

import pandas as pd


X = df[FEATURES]
y = target_df["target_value_spread_fwd_1m"]

df = pd.read_parquet("../data/processed/vinv_inputs_robust.parquet")
target_df = pd.read_parquet("../data/processed/vinv_targets_monthly.parquet")

FEATURES = [
    "mom_1m","mom_3m","mom_12m",
    "ret_m_std","vol_m_sum","div_cash_m"
]

X = df[FEATURES]
y = target_df["target_value_spread_fwd_1m"]

models = {
    "elastic": ElasticNet(alpha=0.01, l1_ratio=0.5),
    "rf": RandomForestRegressor(
        n_estimators=200, max_depth=5, random_state=42
    ),
    "gb": GradientBoostingRegressor(
        n_estimators=200, max_depth=3, random_state=42
    ),
}

results = {}

for name, m in models.items():
    pipe = Pipeline([
        ("scaler", StandardScaler()),
        ("model", m)
    ])
    pipe.fit(X, y)
    results[name] = pipe

print("Models trained:", list(results.keys()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       3 from sklearn.preprocessing import StandardScaler
#       4 from sklearn.pipeline import Pipeline
# ----> 6 X = df[FEATURES]
#       7 y = target_df["target_value_spread_fwd_1m"]
#      10 import pandas as pd
#
# NameError: name 'df' is not defined
